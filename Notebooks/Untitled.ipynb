# %% [markdown]
# Going to merege the two tables together.

# %%
# import the librarys I need
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats
import seaborn as sns
# Mmmmmmm Data Science sandwich...

# %%
spotifydf = pd.read_csv(r"C:\Users\Alexander\Documents\Data Science Boot Camp\Capstone\Copys\Clean data\spotifyclean.csv")

# %%
playlistdf = pd.read_csv(r"C:\Users\Alexander\Documents\Data Science Boot Camp\Capstone\Copys\Clean data\playlistclean.csv")

# %%
spotifydf.head()
# Out:
#    Unnamed: 0                track_id                     artists  \
# 0       20001  3nqQXoyQOWXiESFLlDF1hG        Sam Smith;Kim Petras
# 1       51664  2tTmW7RDtMQtBk7m2rYeSw            Bizarrap;Quevedo
# 2       67356  5ww2BF9slyYgNOk37BlC4u               Manuel Turizo
# 3       20008  4uUG5RXrOk84mYEfFvj3cK     David Guetta;Bebe Rexha
# 4       67358  6Sq7ltF9Qa7SNFBsV5Cogx  Bad Bunny;Chencho Corleone
#
#                               album_name  \
# 0              Unholy (feat. Kim Petras)
# 1  Quevedo: Bzrp Music Sessions, Vol. 52
# 2                             La Bachata
# 3                        I'm Good (Blue)
# 4                       Un Verano Sin Ti
#
#                               track_name  popularity  duration_ms  explicit  \
# 0              Unholy (feat. Kim Petras)         100       156943     False
# 1  Quevedo: Bzrp Music Sessions, Vol. 52          99       198937     False
# 2                             La Bachata          98       162637     False
# ...

# %%
playlistdf.head()
# Out:
#    Unnamed: 0                           user_id  \
# 0           0  9cc0cfd4d7d7885102480dd99e7a90d6
# 1           1  9cc0cfd4d7d7885102480dd99e7a90d6
# 2           2  9cc0cfd4d7d7885102480dd99e7a90d6
# 3           3  9cc0cfd4d7d7885102480dd99e7a90d6
# 4           4  9cc0cfd4d7d7885102480dd99e7a90d6
#
#                          artistname  \
# 0                    Elvis Costello
# 1  Elvis Costello & The Attractions
# 2                      Tiffany Page
# 3  Elvis Costello & The Attractions
# 4                    Elvis Costello
#
#                                            trackname    playlistname
# 0               (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
# 1  (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
# 2                                   7 Years Too Late  HARD ROCK 2010
# 3                              Accidents Will Happen  HARD ROCK 2010
# 4                                             Alison  HARD ROCK 2010

# %%
playlistdf["trackname"].values
# Out:
# array(['(The Angels Wanna Wear My) Red Shoes',
#        "(What's So Funny 'Bout) Peace, Love And Understanding",
#        '7 Years Too Late', ..., 'Man Without a Heart', 'My Woman',
#        'Next Time'], dtype=object)

# %%
spotifydf["track_name"].values
# Out:
# array(['Unholy (feat. Kim Petras)',
#        'Quevedo: Bzrp Music Sessions, Vol. 52', 'La Bachata', ...,
#        'This Christmas Day', 'This Christmas Day',
#        'Не жалею, не зову, не плачу'], dtype=object)

# %%
playlistdf.join(spotifydf, on)
# Out:
#          Unnamed: 0                           user_id  \
# 0                 0  9cc0cfd4d7d7885102480dd99e7a90d6
# 1                 1  9cc0cfd4d7d7885102480dd99e7a90d6
# 2                 2  9cc0cfd4d7d7885102480dd99e7a90d6
# 3                 3  9cc0cfd4d7d7885102480dd99e7a90d6
# 4                 4  9cc0cfd4d7d7885102480dd99e7a90d6
# ...             ...                               ...
# 1047877     1048570  576820c2da503406e16ae9782b3c0e4c
# 1047878     1048571  576820c2da503406e16ae9782b3c0e4c
# 1047879     1048572  576820c2da503406e16ae9782b3c0e4c
# 1047880     1048573  576820c2da503406e16ae9782b3c0e4c
# 1047881     1048574  576820c2da503406e16ae9782b3c0e4c
#
#                                artistname  \
# 0                          Elvis Costello
# 1        Elvis Costello & The Attractions
# 2                            Tiffany Page
# 3        Elvis Costello & The Attractions
# 4                          Elvis Costello
# ...                                   ...
# ...

# %%
# Out:
#                                                     Unnamed: 0 user_id  \
# trackname
# (The Angels Wanna Wear My) Red Shoes                       NaN     NaN
# (What's So Funny 'Bout) Peace, Love And Underst...         NaN     NaN
# 7 Years Too Late                                           NaN     NaN
# Accidents Will Happen                                      NaN     NaN
# Alison                                                     NaN     NaN
# ...                                                        ...     ...
# Locked Down                                                NaN     NaN
# Magnet                                                     NaN     NaN
# Man Without a Heart                                        NaN     NaN
# My Woman                                                   NaN     NaN
# Next Time                                                  NaN     NaN
#
#                                                    artistname trackname  \
# trackname
# ...
